# %% [markdown]
# # Menggunakan Library Tensorflow

# %%
import tensorflow as tf ##jika error,  install tensorflow terlebih dahulu
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import logging
logging.getLogger('matplotlib.font_manager').disabled = True
import random

seed_value = 8
tf.random.set_seed(seed_value) 
np.random.seed(seed_value)      
random.seed(seed_value)

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist  
                                                 
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 6us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 10s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
train_labels
# Out:
# array([9, 0, 0, ..., 3, 0, 5], dtype=uint8)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
len(test_labels)
# Out:
# 10000

# %%
plt.figure() 
plt.imshow(train_images[0]) 
plt.colorbar() 
plt.grid(False)
plt.show()

# %%
train_images = train_images.reshape(-1, 28, 28, 1).astype('float32') / 255
test_images = test_images.reshape(-1, 28, 28, 1).astype('float32') / 255

# %%
plt.figure(figsize=(10,10)) 
for i in range(25): 
    plt.subplot(5,5,i+1) 
    plt.xticks([]) 
    plt.yticks([]) 
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary) 
    plt.xlabel(class_names[train_labels[i]]) 
plt.show()

# %%
model_tf = tf.keras.Sequential([ 
    tf.keras.layers.Input(shape=(28, 28)), 
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),  
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(10)
])

# %%
model_tf.compile(optimizer='adam', 
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
              metrics=['accuracy'])

# %%
from keras.callbacks import EarlyStopping


early_stopping = EarlyStopping(
    monitor='val_accuracy', 
    patience=5,
    min_delta=0.0001, 
    restore_best_weights=True  
)


history = model_tf.fit(
    train_images, train_labels,
    epochs=40,
    validation_data=(test_images, test_labels),
    callbacks=[early_stopping]  
)
# Out:
# Epoch 1/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7467 - loss: 0.7260 - val_accuracy: 0.8459 - val_loss: 0.4320
# Epoch 2/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8430 - loss: 0.4382 - val_accuracy: 0.8553 - val_loss: 0.3970
# Epoch 3/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8555 - loss: 0.3958 - val_accuracy: 0.8638 - val_loss: 0.3728
# Epoch 4/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8635 - loss: 0.3730 - val_accuracy: 0.8657 - val_loss: 0.3800
# Epoch 5/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8690 - loss: 0.3595 - val_accuracy: 0.8715 - val_loss: 0.3551
# Epoch 6/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8740 - loss: 0.3478 - val_accuracy: 0.8723 - val_loss: 0.3543
# Epoch 7/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8777 - loss: 0.3368 - val_accuracy: 0.8712 - val_loss: 0.3568
# Epoch 8/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8819 - loss: 0.3248 - val_accuracy: 0.8768 - val_loss: 0.3451
# Epoch 9/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8831 - loss: 0.3168 - val_accuracy: 0.8759 - val_loss: 0.3481
# Epoch 10/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8874 - loss: 0.3118 - val_accuracy: 0.8790 - val_loss: 0.3405
# Epoch 11/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8885 - loss: 0.3050 - val_accuracy: 0.8765 - val_loss: 0.3444
# Epoch 12/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8896 - loss: 0.2983 - val_accuracy: 0.8779 - val_loss: 0.3447
# Epoch 13/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8902 - loss: 0.2975 - val_accuracy: 0.8787 - val_loss: 0.3418
# Epoch 14/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8897 - loss: 0.2920 - val_accuracy: 0.8820 - val_loss: 0.3349
# Epoch 15/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8945 - loss: 0.2873 - val_accuracy: 0.8818 - val_loss: 0.3351
# Epoch 16/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8935 - loss: 0.2838 - val_accuracy: 0.8816 - val_loss: 0.3406
# Epoch 17/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8969 - loss: 0.2790 - val_accuracy: 0.8813 - val_loss: 0.3399
# Epoch 18/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8976 - loss: 0.2756 - val_accuracy: 0.8846 - val_loss: 0.3395
# Epoch 19/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8987 - loss: 0.2708 - val_accuracy: 0.8835 - val_loss: 0.3351
# Epoch 20/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9013 - loss: 0.2644 - val_accuracy: 0.8819 - val_loss: 0.3349
# Epoch 21/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9015 - loss: 0.2647 - val_accuracy: 0.8818 - val_loss: 0.3505
# Epoch 22/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9023 - loss: 0.2601 - val_accuracy: 0.8826 - val_loss: 0.3498
# Epoch 23/40
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9038 - loss: 0.2576 - val_accuracy: 0.8838 - val_loss: 0.3455

# %%
fig = plt.figure()
plt.plot(history.history['val_accuracy'], color='teal', label='Validation Accuracy')  
plt.plot(history.history['accuracy'], color='orange', label='Train Accuracy')
plt.legend(loc="upper left")
plt.show()

# %%
fig = plt.figure()
plt.plot(history.history['val_loss'], color = 'blue', label = 'Validation Loss')
plt.plot(history.history['loss'], color = 'orange', label = 'Train Loss')
plt.legend(loc = "upper left")
plt.show()

# %%
test_loss, test_acc_tf = model_tf.evaluate(test_images, test_labels, verbose=2) 
                                                                                
print('\nTest accuracy:', test_acc_tf)
# Out:
# 313/313 - 0s - 589us/step - accuracy: 0.8846 - loss: 0.3395
#
# Test accuracy: 0.8845999836921692

# %%
probability_model = tf.keras.Sequential([model_tf, 
                                         tf.keras.layers.Softmax()])

# %%
predictions_tf = probability_model.predict(test_images)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 756us/step

# %%
predictions_tf[0]
# Out:
# array([6.3982253e-07, 8.6384427e-10, 8.3487578e-11, 1.0584233e-11,
#        9.4631469e-10, 6.4832438e-04, 5.1121596e-09, 9.8980009e-04,
#        8.5312091e-10, 9.9836129e-01], dtype=float32)

# %%
np.argmax(predictions_tf[0])
# Out:
# 9

# %%
test_labels[0]
# Out:
# 9

# %%
def plot_image(i, predictions_array, true_label, img):

  true_label, img = true_label[i], img[i]                                                      
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])
  plt.imshow(img, cmap=plt.cm.binary)


  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                100*np.max(predictions_array),
                                class_names[true_label]),
                                color=color)

def plot_value_array(i, predictions_array, true_label): 
                                                       
  true_label = true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %%
i = 5 
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, predictions_tf[i], test_labels, test_images)
plt.subplot(1,2,2)
plot_value_array(i, predictions_tf[i], test_labels)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

num_rows = 5
num_cols = 4
num_images = num_rows * num_cols

correct_predictions = [np.argmax(predictions_tf[i]) == test_labels[i] for i in range(num_images)]
average_accuracy = np.mean(correct_predictions) * 100  

plt.figure(figsize=(2 * 2 * num_cols, 2 * num_rows))
for i in range(num_images):
    plt.subplot(num_rows, 2 * num_cols, 2 * i + 1)
    plot_image(i, predictions_tf[i], test_labels, test_images)
    border_color = 'green' if correct_predictions[i] else 'red'
    plt.gca().patch.set_edgecolor(border_color)
    plt.gca().patch.set_linewidth(3)

    plt.subplot(num_rows, 2 * num_cols, 2 * i + 2)
    plot_value_array(i, predictions_tf[i], test_labels)

plt.suptitle(f'Akurasi Rata-rata: {average_accuracy:.2f}%')
plt.tight_layout()
plt.show()

# %%
img = test_images[1]

print(img.shape)
# Out:
# (28, 28, 1)

# %%
img = (np.expand_dims(img,0))

print(img.shape)
# Out:
# (1, 28, 28, 1)

# %%
predictions_single = probability_model.predict(img)

print(predictions_single)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# [[4.52464491e-07 3.28482272e-18 9.98824060e-01 1.10598862e-17
#   1.14498474e-03 3.07123479e-16 3.04589830e-05 1.13991233e-26
#   1.91073963e-14 1.10677035e-23]]

# %%
plot_value_array(1, predictions_single[0], test_labels) 
_ = plt.xticks(range(10), class_names, rotation=45) 
plt.show()

# %%
np.argmax(predictions_single[0])
# Out:
# 2

# %%
df_test = pd.DataFrame({
    'Target': test_labels,  
    'Predicted': np.argmax(predictions_tf, axis=1),  
    'Proba_0': predictions_tf[:, 0],  
    'Proba_1': predictions_tf[:, 1]  
})

pixels = test_images.reshape(len(test_images), -1)

df_pixels = pd.DataFrame(pixels, columns=[f'pixel{i+1}' for i in range(28*28)])

df_test = pd.concat([df_test, df_pixels], axis=1)

# %%
df_plot = df_test.sample(16, random_state=8).copy()
fig, ax = plt.subplots(4, 4, figsize=(10, 10))

rata2_accuracy = (df_test['Target'] == df_test['Predicted']).mean() * 100

for i, axi in enumerate(ax.flat):
    p0 = df_plot['Proba_0'].values[i]
    p1 = df_plot['Proba_1'].values[i]

    predicted_class = df_plot['Predicted'].values[i]
    prediction_probability = max(p0, p1) * 100

    true_class = df_plot['Target'].values[i]

    pixels = df_plot[[f'pixel{j}' for j in range(1, 28*28 + 1)]].values[i].reshape(28, 28)
    axi.imshow(pixels, cmap='viridis')

    axi.set(xticks=[], yticks=[],
            xlabel=f"True: {true_class}\nPred: {predicted_class}\nProb: {prediction_probability:.2f}%")

    edge_color = 'green' if predicted_class == true_class else 'red'
    axi.spines[:].set_edgecolor(edge_color)
    axi.spines[:].set_linewidth(3)

fig.suptitle(f'Contoh gambar yang diklasifikasikan dari set pengujian\n'
             f'Batas hijau: klasifikasi benar\nAkurasi Keseluruhan: {rata2_accuracy:.2f}%')

fig.tight_layout()
plt.show()

# %% [markdown]
# # Menggunakan Library Scikit-Learn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns
import tensorflow as tf

# %%
import warnings
warnings.filterwarnings("ignore")
warnings.simplefilter("ignore")

# %%
from sklearn.datasets import fetch_openml
fashion_mnist = fetch_openml('Fashion-MNIST', version=1)

train_images = fashion_mnist.data[:60000] 
train_labels = fashion_mnist.target[:60000].astype(int)
test_images = fashion_mnist.data[60000:]
test_labels = fashion_mnist.target[60000:].astype(int)

# %%
train_images = train_images / 255.0
test_images = test_images / 255.0

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer, log_loss
from sklearn.model_selection import train_test_split
import numpy as np

train_images_split, val_images, train_labels_split, val_labels = train_test_split(
    train_images, train_labels, test_size=0.2, random_state=8
)

model_sklearn = MLPClassifier(hidden_layer_sizes=(128,300),
                      activation='relu',
                      alpha=0.0001,
                      learning_rate_init=0.001,
                      early_stopping=True,
                      validation_fraction=0.2,
                      n_iter_no_change=10,
                      random_state=8,

                      verbose=True)

model_sklearn.fit(train_images_split, train_labels_split)
training_loss = model_sklearn.loss_curve_
# Out:
# Iteration 1, loss = 0.61505400
# Validation score: 0.844375
# Iteration 2, loss = 0.41607327
# Validation score: 0.846458
# Iteration 3, loss = 0.37089796
# Validation score: 0.870625
# Iteration 4, loss = 0.33993353
# Validation score: 0.872188
# Iteration 5, loss = 0.31917437
# Validation score: 0.873437
# Iteration 6, loss = 0.30472185
# Validation score: 0.872812
# Iteration 7, loss = 0.28885940
# Validation score: 0.876042
# Iteration 8, loss = 0.27713165
# Validation score: 0.883437
# Iteration 9, loss = 0.26613379
# Validation score: 0.882500
# Iteration 10, loss = 0.25246590
# Validation score: 0.888854
# Iteration 11, loss = 0.24587660
# Validation score: 0.886771
# Iteration 12, loss = 0.22869461
# Validation score: 0.884479
# Iteration 13, loss = 0.22942152
# Validation score: 0.889583
# Iteration 14, loss = 0.22142805
# Validation score: 0.888229
# Iteration 15, loss = 0.20953640
# Validation score: 0.888854
# Iteration 16, loss = 0.20770761
# Validation score: 0.884479
# Iteration 17, loss = 0.19884850
# Validation score: 0.886250
# Iteration 18, loss = 0.18665505
# Validation score: 0.892292
# Iteration 19, loss = 0.18323378
# Validation score: 0.892396
# Iteration 20, loss = 0.17779889
# Validation score: 0.888854
# Iteration 21, loss = 0.17086653
# Validation score: 0.883750
# Iteration 22, loss = 0.17357390
# Validation score: 0.884375
# Iteration 23, loss = 0.16306445
# Validation score: 0.894583
# Iteration 24, loss = 0.15817221
# Validation score: 0.893646
# Iteration 25, loss = 0.15246483
# Validation score: 0.889896
# Iteration 26, loss = 0.14842186
# Validation score: 0.888958
# Iteration 27, loss = 0.14218789
# Validation score: 0.893854
# Iteration 28, loss = 0.13725037
# Validation score: 0.887292
# Iteration 29, loss = 0.12825347
# Validation score: 0.893646
# Iteration 30, loss = 0.12527825
# Validation score: 0.894792
# Iteration 31, loss = 0.12695086
# Validation score: 0.890417
# Iteration 32, loss = 0.12167668
# Validation score: 0.894375
# Iteration 33, loss = 0.11644767
# Validation score: 0.892604
# Iteration 34, loss = 0.10874811
# Validation score: 0.885312
# Iteration 35, loss = 0.10816860
# Validation score: 0.895000
# Iteration 36, loss = 0.10318840
# Validation score: 0.891354
# Iteration 37, loss = 0.10121747
# Validation score: 0.892083
# Iteration 38, loss = 0.09826613
# Validation score: 0.895521
# Iteration 39, loss = 0.09617445
# Validation score: 0.890521
# Iteration 40, loss = 0.09128055
# Validation score: 0.890104
# Iteration 41, loss = 0.08478295
# Validation score: 0.890521
# Iteration 42, loss = 0.08221296
# Validation score: 0.895625
# Iteration 43, loss = 0.07641040
# Validation score: 0.893229
# Iteration 44, loss = 0.07437709
# Validation score: 0.893333
# Iteration 45, loss = 0.08427284
# Validation score: 0.889792
# Iteration 46, loss = 0.07147596
# Validation score: 0.890000
# Iteration 47, loss = 0.07765706
# Validation score: 0.891875
# Iteration 48, loss = 0.06983107
# Validation score: 0.891250
# Iteration 49, loss = 0.06796796
# Validation score: 0.895521
# Iteration 50, loss = 0.06018445
# Validation score: 0.897917
# Iteration 51, loss = 0.06771975
# Validation score: 0.886667
# Iteration 52, loss = 0.06515917
# Validation score: 0.889167
# Iteration 53, loss = 0.05919381
# Validation score: 0.889062
# Iteration 54, loss = 0.06370698
# Validation score: 0.894062
# Iteration 55, loss = 0.05704447
# Validation score: 0.888750
# Iteration 56, loss = 0.05117820
# Validation score: 0.894479
# Iteration 57, loss = 0.04185755
# Validation score: 0.891354
# Iteration 58, loss = 0.05561990
# Validation score: 0.887500
# Iteration 59, loss = 0.04887717
# Validation score: 0.892917
# Iteration 60, loss = 0.04863405
# Validation score: 0.890000
# Iteration 61, loss = 0.04677074
# Validation score: 0.891250
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.

# %%
from sklearn.model_selection import learning_curve

train_sizes, train_scores, val_scores = learning_curve(
    model_sklearn, train_images,train_labels, train_sizes=np.linspace(0.1, 1.0, 10), cv=5,
    scoring='neg_log_loss', random_state=8, n_jobs=-1)

train_loss_mean = -train_scores.mean(axis=1)
val_loss_mean = -val_scores.mean(axis=1)

plt.figure(figsize=(10, 6))
plt.plot(train_sizes, train_loss_mean, label='Training Loss')
plt.plot(train_sizes, val_loss_mean, label='Validation Loss')
plt.xlabel('Training Set Size')
plt.ylabel('Loss')
plt.title('Learning Curve (Training vs Validation Loss)')
plt.legend()
plt.show()

# %%
test_predictions = model_sklearn.predict(test_images)
test_acc_sklearn = accuracy_score(test_labels, test_predictions)
print('\nTest accuracy:', test_acc_sklearn)
# Out:
# Test accuracy: 0.8866

# %%
print("\nClassification Report:\n", classification_report(test_labels, test_predictions))

predictions_proba = model_sklearn.predict_proba(test_images)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.84      0.81      0.83      1000
#            1       0.99      0.97      0.98      1000
#            2       0.78      0.83      0.80      1000
#            3       0.88      0.91      0.89      1000
#            4       0.80      0.84      0.82      1000
#            5       0.97      0.96      0.96      1000
#            6       0.73      0.68      0.70      1000
#            7       0.95      0.94      0.95      1000
#            8       0.98      0.96      0.97      1000
#            9       0.94      0.97      0.96      1000
#
#     accuracy                           0.89     10000
#    macro avg       0.89      0.89      0.89     10000
# weighted avg       0.89      0.89      0.89     10000

# %%
predictions_sklearn = model_sklearn.predict_proba(test_images)
print(predictions_sklearn[0])
print("Predicted label fro first image:", np.argmax(predictions_sklearn[0]))

print("Actual label for first image:", test_labels.iloc[0])
# Out:
# [4.78598010e-14 2.57170613e-15 5.76680830e-12 2.40906992e-18
#  3.69859932e-10 5.44426235e-08 5.97102112e-13 1.77332075e-06
#  2.91943799e-12 9.99998172e-01]
# Predicted label fro first image: 9
# Actual label for first image: 9

# %%
def plot_image(i, predictions_array, true_label, img):

    true_label, img = true_label.iloc[i], img.iloc[i].values.reshape(28, 28) 
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])

    plt.imshow(img, cmap=plt.cm.binary)

    predicted_label = np.argmax(predictions_array)
    color = 'blue' if predicted_label == true_label else 'red'

    plt.xlabel(f"{class_names[predicted_label]} {100*np.max(predictions_array):.2f}% ({class_names[true_label]})", color=color)

def plot_value_array(i, predictions_array, true_label):

    true_label = true_label.iloc[i] 
    plt.grid(False)
    plt.xticks(range(10))
    plt.yticks([])
    thisplot = plt.bar(range(10), predictions_array, color="#777777")
    plt.ylim([0, 1])
    predicted_label = np.argmax(predictions_array)

    thisplot[predicted_label].set_color('red')
    thisplot[true_label].set_color('blue')

# %%
i = 1
plt.figure(figsize=(6, 3))
plt.subplot(1, 2, 1)
plot_image(i, predictions_sklearn[i], test_labels, test_images)
plt.subplot(1, 2, 2)
plot_value_array(i, predictions_sklearn[i], test_labels)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

num_rows = 5
num_cols = 4
num_images = num_rows * num_cols

correct_predictions = [np.argmax(predictions_sklearn[i]) == test_labels.iloc[i] for i in range(num_images)]
average_accuracy = np.mean(correct_predictions) * 100

plt.figure(figsize=(2 * 2 * num_cols, 2 * num_rows))
for i in range(num_images):

    plt.subplot(num_rows, 2 * num_cols, 2 * i + 1)
    plot_image(i, predictions_sklearn[i], test_labels, test_images)
    border_color = 'green' if correct_predictions[i] else 'red'
    plt.gca().patch.set_edgecolor(border_color)
    plt.gca().patch.set_linewidth(3)

    plt.subplot(num_rows, 2 * num_cols, 2 * i + 2)
    plot_value_array(i, predictions_sklearn[i], test_labels)

plt.suptitle(f'Akurasi Rata-rata: {average_accuracy:.2f}%')
plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

n_samples = 10000

df_test = pd.DataFrame({
    'Target': test_labels,
    'Predicted': np.argmax(predictions_sklearn, axis=1),
    'Proba_0' : predictions_sklearn[:, 0],
    'Proba_1' : predictions_sklearn[:, 1]
})

df_test['Proba_0'] = df_test['Proba_0'] / (df_test['Proba_0'] + df_test['Proba_1'])
df_test['Proba_1'] = 1 - df_test['Proba_0']

for i in range(1, 2828 + 1):
    df_test[f'pixel{i}'] = np.random.randint(0, 256, n_samples)

df_plot = df_test.sample(16, random_state=8).copy()

fig, ax = plt.subplots(4, 4, figsize=(10, 10))
rata2_accuracy = (df_test['Target'] == df_test['Predicted']).mean() * 100

for i, axi in enumerate(ax.flat):
    p0 = df_plot['Proba_0'].values[i]
    p1 = df_plot['Proba_1'].values[i]
    predicted_class = df_plot['Predicted'].values[i]
    prediction_probability = max(p0, p1) * 100
    true_class = df_plot['Target'].values[i]
    pixels = df_plot[[f'pixel{j}' for j in range(1, 28*28 + 1)]].values[i].reshape(28, 28)
    axi.imshow(pixels, cmap='viridis')
    axi.set(xticks=[], yticks=[],
            xlabel=f"True: {true_class}\nPred: {predicted_class}\nProb: {prediction_probability:.2f}%")
    edge_color = 'green' if predicted_class == true_class else 'red'
    for spine in axi.spines.values():
        spine.set_edgecolor(edge_color)
        spine.set_linewidth(3)

fig.suptitle(f'Contoh gambar yang diklasifikasikan dari set pengujian\n'
             f'Batas hijau: klasifikasi benar\nAkurasi Keseluruhan: {rata2_accuracy:.2f}%')

fig.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_image(i, predictions_array, true_label, img):

    true_label, img = true_label.iloc[i], img.iloc[i].values.reshape(28, 28)

    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(img, cmap='gray') 

    predicted_label = np.argmax(predictions_array)
    color = 'blue' if predicted_label == true_label else 'red'

    plt.xlabel(f"{class_names[predicted_label]} {100*np.max(predictions_array):.2f}% ({class_names[true_label]})", color=color)


def plot_value_array(i, predictions_array, true_label):
    true_label = true_label.iloc[i]
    plt.grid(False)
    plt.xticks(range(10))
    plt.yticks([])
    thisplot = plt.bar(range(10), predictions_array, color="#77777777")
    plt.ylim([0, 1])
    predicted_label = np.argmax(predictions_array)

    thisplot[predicted_label].set_color('red')
    thisplot[true_label].set_color('blue')

i = 19
plt.figure(figsize=(6, 3))

plt.subplot(1, 2, 1)
plot_image(i, predictions_sklearn[i], test_labels, test_images)

plt.subplot(1, 2, 2)
plot_value_array(i, predictions_sklearn[i], test_labels)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def save_image_only(i, true_label, img):
    img = img.iloc[i].values.reshape(28, 28)

    plt.imshow(img, cmap='gray')
    plt.axis('off')
    plt.savefig(f"image_only{i}.jpeg", bbox_inches='tight', pad_inches=0)
    plt.close()

i = 19
save_image_only(i, test_labels, test_images)

# %%
import pandas as pd

data = {
    'Model': ['TensorFlow', 'Scikit-Learn'],
    'Accuracy': [test_acc_tf, test_acc_sklearn],
    'Architecture': ['Neural Network (2 hidden layers)', 'MLP (2 hidden layer)'],
    'Early Stopping': ['Yes', 'Yes']
}

comparison_df = pd.DataFrame(data)

best_model = comparison_df.loc[comparison_df['Accuracy'].idxmax()]

print("Comparison of Model Performance:")
print(comparison_df)

print("\nBest Model Based on Accuracy")
print(best_model)
# Out:
# Comparison of Model Performance:
#           Model  Accuracy                      Architecture Early Stopping
# 0    TensorFlow    0.8846  Neural Network (2 hidden layers)            Yes
# 1  Scikit-Learn    0.8866              MLP (2 hidden layer)            Yes
#
# Best Model Based on Accuracy
# Model                     Scikit-Learn
# Accuracy                        0.8866
# Architecture      MLP (2 hidden layer)
# Early Stopping                     Yes
# Name: 1, dtype: object

# %%
import pickle

with open('best_model.pkl', 'wb') as file:
    pickle.dump(model_sklearn, file)

# %%
import pickle
import tensorflow as tf

model_tf.save('best_model_tf.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
